# %% [markdown]
# W3A1: Viet mot chuong trinh nhap vao so nguyen n va in ra so nguoc lai

# %%
n = int(input())
if 100 <= n <= 999:
    a = n // 100
    b = (n // 10) % 10
    c = n % 10
print(f"{c}{b}{a}")
# Out:
# 321

# %% [markdown]
# W3A2: Hoán đổi hai số không sử dụng biến tạm thời. Sử dụng phép toán XOR bitwise (^) để hoán đổi giá trị của hai biến.

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))

# Thuật toán XOR hoán đổi
a = a ^ b
b = a ^ b
a = a ^ b

print(f"Sau khi hoán đổi: a = {a}, b = {b}")
# Out:
# Sau khi hoán đổi: a = 2, b = 1

# %% [markdown]
# W3A3: Kiểm tra xem một số có phải là lũy thừa của 2 hay không. Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.

# %%
n = int(input())

if n > 0 and (n & (n - 1)) == 0:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A4: Viết chương trình chia một số m cho n, kết quả thu được làm tròn xuống.

# %%
m = int(input("Nhập m: "))
n = int(input("Nhập n: "))

kq = m // n
print(kq)

# %% [markdown]
# W3A5:  Viết chương trình chia một số m cho n, kết quả thu được làm tròn lên.

# %%
import math

m = float(input("Nhập m: "))
n = float(input("Nhập n: "))

kq = math.ceil(m / n)
print(kq)

# %% [markdown]
# W3A6: Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# W3A7:  Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a = int(input())
b = int(input())

if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A8: Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a = input()
b = input()

if len(a) > len(b):
    print("True")
else:
    print("False")

# %% [markdown]
# W3A9: Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu có in ra "Yes". Ngược lại in ra "No".

# %%
a = int(input())
b = int(input())
c = int(input())

if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A10: Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())

print(max(a, b, c, d))

# %% [markdown]
# W3A11: Nhập vào 3 số nguyên dương a, b, c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay "Tam giác thường".

# %%
a = int(input())
b = int(input())
c = int(input())

if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or b == c or a == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")

# %% [markdown]
# W3A12: Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in r "No".

# %%
n = int(input())

if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A13: Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:

# %%
kwh = float(input("Nhập số kWh: "))
tien = 0

if kwh <= 50:
    tien = kwh * 1500
elif kwh <= 100:
    tien = (50 * 1500) + (kwh - 50) * 2000
else:
    tien = (50 * 1500) + (50 * 2000) + (kwh - 100) * 3000

print(f"Số tiền điện: {tien}đ")

# %% [markdown]
# W3A14: Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a = float(input())
b = float(input())

if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    x = -b / a
    print(f"{x:.2f}")

# %% [markdown]
# W3A15: Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực

# %%
diem = float(input())

if diem >= 8.0:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
